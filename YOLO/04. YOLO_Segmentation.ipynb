# %%
# !pip install ultralytics

# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.5/235.7 GB disk)

# %%
# !yolo segment predict model=yolov8n-seg source='./bus.jpg'
# Out:
# ...
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,404,320 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 54.8ms
# Speed: 13.2ms preprocess, 54.8ms inference, 98.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('./runs/segment/predict/bus.jpg')

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')
results = model(source='./bus.jpg', save=True)
# Out:
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 84.5ms
# Speed: 5.5ms preprocess, 84.5ms inference, 30.0ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/segment/predict2

# %%
img = mpimg.imread('./runs/segment/predict2/bus.jpg')

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
model = YOLO('yolov8n-seg.pt')
results = model.train(data='coco8-seg.yaml', epochs=100, imgsz=640)

# %%
img = mpimg.imread('./runs/segment/train/results.png')

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread('./runs/segment/train/val_batch0_pred.jpg')

plt.imshow(img)
plt.axis('off')
plt.show()
